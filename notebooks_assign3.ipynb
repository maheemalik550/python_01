# %%
# Q:1  Simple Calculator

num1 = float(input("Enter first number: "))
num2 = float(input("Enter second number: "))
operator = input("Enter operator (+, -, *, /, **): ")

if operator == "+":
    print("Result:", num1 + num2)

elif operator == "-":
    print("Result:", num1 - num2)

elif operator == "*":
    print("Result:", num1 * num2)

elif operator == "/":
    if num2 != 0:
        print("Result:", num1 / num2)
    else:
        print("Error: Cannot divide by zero")

elif operator == "**":
    print("Result:", num1 ** num2)

else:
    print("Invalid operator")
# Out:
# Enter first number:  8
# Enter second number:  8
# Enter operator (+, -, *, /, **):  *
# Result: 64.0

# %%
# Q:2
a = ["laiba", 5, "apple", 10]

for item in a:
    if isinstance(item, int):
        print("Numeric value exists")
        break
else:
    print("Numeric value not exists")
# Out:
# Numeric value exists

# %%
a = ["laiba", "hello", "apple"]

for item in a:
    if isinstance(item, int):
        print("Numeric value exists")
        break
else:
    print("Numeric value not exists")
# Out:
# Numeric value not exists

# %%
# Q:3
# Existing dictionary
d = {"city": "karachi"}

# Add new key
d["country"] = "Pakistan"
d["name"] = "laiba"
d["age"] = 18

# Print dict
print(d)
# Out:
# {'city': 'karachi', 'country': 'Pakistan', 'name': 'laiba', 'age': 18}

# %%
# Q:4
d = {"a": 10, "b": 20, "c": 5, "d": 8}

# Sum of all values
total = sum(d.values())

print("Total:", total)
# Out:
# Total: 43

# %%
# Q:5
a = [1, 2, 3, 2, 4, 1]
duplicates = []

for item in a:
    if a.count(item) > 1 and item not in duplicates:
        duplicates.append(item)

print("Duplicates:", duplicates)
# Out:
# Duplicates: [1, 2]

# %%
d = {"name": "Laiba", "age": 18}

key_to_check = "age"  

if key_to_check in d:
    print(f"Key '{key_to_check}' exists in the dictionary.")
else:
    print(f"Key '{key_to_check}' does not exist in the dictionary.")
# Out:
# Key 'age' exists in the dictionary.
